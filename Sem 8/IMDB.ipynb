# %%
# IMDB Sentiment Classification
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,Dense,GlobalAveragePooling1D

(x,y),(a,b)=imdb.load_data(num_words=5000)

x=pad_sequences(x,maxlen=200)
a=pad_sequences(a,maxlen=200)
print(x,a)
m=Sequential([
    Embedding(5000,32),
    GlobalAveragePooling1D(),
    Dense(1,activation='sigmoid')
])

m.compile("adam","binary_crossentropy",metrics=["accuracy"])

m.fit(x,y,epochs=2,batch_size=128)

print(m.evaluate(a,b))
# Out:
# [[   5   25  100 ...   19  178   32]
#  [   0    0    0 ...   16  145   95]
#  [   0    0    0 ...    7  129  113]
#  ...
#  [   0    0    0 ...    4 3586    2]
#  [   0    0    0 ...   12    9   23]
#  [   0    0    0 ...  204  131    9]] [[   0    0    0 ...   14    6  717]
#  [1987    2   45 ...  125    4 3077]
#  [4468  189    4 ...    9   57  975]
#  ...
#  [   0    0    0 ...   21  846    2]
#  [   0    0    0 ... 2302    7  470]
#  [   0    0    0 ...   34 2005 2643]]
# Epoch 1/2
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6671 - loss: 0.6615
# Epoch 2/2
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7760 - loss: 0.5581
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 797us/step - accuracy: 0.8071 - loss: 0.5100
# [0.510015070438385, 0.8071200251579285]
